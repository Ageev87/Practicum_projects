# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Подскажи, пожалуйста, свое имя:)
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b> <br>
# Добрый день, Евгения!<br>
# Меня зовут Павел.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <s="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Паша,  привет!
# </div>

# %% [markdown]
# # Описание данных
#
# # Контекст
# Вы — аналитик крупного интернет-магазина. Вместе с отделом маркетинга вы подготовили список гипотез для увеличения выручки.
# Приоритизируйте гипотезы, запустите A/B-тест и проанализируйте результаты.
#
# # Данные для первой части
# <b>Файл </b> `/datasets/hypothesis.csv.`.<br>
# `Hypothesis` — краткое описание гипотезы;<br>
# `Reach` — охват пользователей по 10-балльной шкале;<br>
# `Impact` — влияние на пользователей по 10-балльной шкале;<br>
# `Confidence` — уверенность в гипотезе по 10-балльной шкале;<br>
# `Efforts` — затраты ресурсов на проверку гипотезы по 10-балльной шкале. Чем больше значение Efforts, тем дороже проверка гипотезы.
# # Данные для второй части
# <b>Файл </b> `/datasets/orders.csv`.<br>
# `transactionId` — идентификатор заказа;<br>
# `visitorId` — идентификатор пользователя, совершившего заказ;<br>
# `date` — дата, когда был совершён заказ;<br>
# `revenue` — выручка заказа;<br>
# `group` — группа A/B-теста, в которую попал заказ.<br>
# <b>Файл </b>`/datasets/visitors.csv.`.<br>
# `date` — дата;<br>
# `group` — группа A/B-теста;<br>
# `visitors` — количество пользователей в указанную дату в указанной группе A/B-теста<br>
# # Описание проекта
# # Контекст
# Вы — аналитик крупного интернет-магазина. Вместе с отделом маркетинга вы подготовили список гипотез для увеличения выручки.
# Приоритизируйте гипотезы, запустите A/B-тест и проанализируйте результаты.
# # Часть 1. Приоритизация гипотез.
# В <b>Файл </b> `/datasets/hypothesis.csv` 9 гипотез по увеличению выручки интернет-магазина с указанными параметрами Reach, Impact, Confidence, Effort.
# # Задача
# Примените фреймворк ICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# Примените фреймворк RICE для приоритизации гипотез. Отсортируйте их по убыванию приоритета.
# Укажите, как изменилась приоритизация гипотез при применении RICE вместо ICE. Объясните, почему так произошло.
# # Часть 2. Анализ A/B-теста
# Вы провели A/B-тест и получили результаты, которые описаны в <b>файлах </b> `/datasets/orders.csv` и `/datasets/visitors.csv`.
# # Задача
# Проанализируйте A/B-тест:
# 1. Постройте график кумулятивной выручки по группам. Сделайте выводы и предположения.
# 2. Постройте график кумулятивного среднего чека по группам. Сделайте выводы и предположения.
# 3. Постройте график относительного изменения кумулятивного среднего чека группы B к группе A. Сделайте выводы и предположения.
# 4. Постройте график кумулятивного среднего количества заказов на посетителя по группам. Сделайте выводы и предположения.
# 5. Постройте график относительного изменения кумулятивного среднего количества заказов на посетителя группы B к группе A. Сделайте выводы и предположения.
# 6. Постройте точечный график количества заказов по пользователям. Сделайте выводы и предположения.
# 7. Посчитайте 95-й и 99-й перцентили количества заказов на пользователя. Выберите границу для определения аномальных пользователей.
# 8. Постройте точечный график стоимостей заказов. Сделайте выводы и предположения.
# 9. Посчитайте 95-й и 99-й перцентили стоимости заказов. Выберите границу для определения аномальных заказов.
# 10. Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным. Сделайте выводы и предположения.
# 11. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным. Сделайте выводы и предположения.
# 12. Посчитайте статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным. Сделайте выводы и предположения.
# 13. Посчитайте статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным. Сделайте выводы и предположения.
# 14. Примите решение по результатам теста и объясните его. Варианты решений:
#     1. Остановить тест, зафиксировать победу одной из групп.
#     2. Остановить тест, зафиксировать отсутствие различий между группами.
#     3. Продолжить тест.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Супер, что добавил описание и привел детальный план изучения проекта, так будет легче каждому соореентироваться в работе!
# </div>

# %% [markdown]
# # Часть 1:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
# Сброс ограничений на количество символов в записи
pd.set_option('display.max_colwidth', None) # Аналогично pd.options.display.max_colwidth = False. Также нет разницы False или None

# %%
#Чтение Сохранение дф 
hypothesis = pd.read_csv('/datasets/hypothesis.csv')

# %%
#Выведем таблицу:
hypothesis
# Out:
#                                                                                                      Hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
# 5                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Данные загружены верно! Молодец, что применил настройку, так с гипотезами познакомились в полном объеме.
# </div>

# %%
#Вывод основной информации
hypothesis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Hypothesis  9 non-null      object
#  1   Reach       9 non-null      int64
#  2   Impact      9 non-null      int64
#  3   Confidence  9 non-null      int64
#  4   Efforts     9 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 488.0+ bytes

# %%
#Выведем статистические данные:
hypothesis.describe()
# Out:
#            Reach     Impact  Confidence    Efforts
# count   9.000000   9.000000    9.000000   9.000000
# mean    4.777778   4.777778    5.555556   4.888889
# std     3.153481   3.192874    3.045944   2.803767
# min     1.000000   1.000000    1.000000   1.000000
# 25%     3.000000   3.000000    3.000000   3.000000
# 50%     3.000000   3.000000    7.000000   5.000000
# 75%     8.000000   7.000000    8.000000   6.000000
# max    10.000000  10.000000    9.000000  10.000000

# %%
#Проверим пропуски:
hypothesis.isna().sum()
# Out:
# Hypothesis    0
# Reach         0
# Impact        0
# Confidence    0
# Efforts       0
# dtype: int64

# %%
#Рассмотрим явные дубликаты:
print(f'Количество явных дубликатов: {hypothesis.duplicated().sum()}') # Хотя и без проверки понятно было...
# Out:
# Количество явных дубликатов: 0

# %% [markdown]
# В целом, пропущенных данных, дубликатов нет, типы данных присвоены корректно, единственное к чему можно придраться - наименования колонок с заглавной буквы - приведу к нижнему регистру.

# %%
hypothesis.columns = hypothesis.columns.str.lower()
hypothesis.head(5)
# Out:
#                                                                                                      hypothesis  \
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 4                              Изменить цвет фона главной страницы, чтобы увеличить вовлеченность пользователей
#
#    reach  impact  confidence  efforts
# 0      3      10           8        6
# 1      2       5           4       10
# 2      8       3           7        3
# 3      8       3           3        8
# 4      3       1           1        1

# %% [markdown]
# <b>Вывод:</b><br>
# Пропущенных данных, дубликатов нет, типы данных присвоены корректно, наименования колонок приведены к нижнему регистру.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Хорошо, такой формат намного лучше!
# </div>

# %% [markdown]
# Рассчитаем значение фреймворка `ICE` (от англ. impact, confidence, effort / ease «влияние, уверенность, усилия / простота») для приоритизации гипотез.

# %%
hypothesis['ice'] = round(hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts'], 1)
hypothesis.sort_values('ice', ascending = False).reset_index(drop=True)
# Out:
#                                                                                                      hypothesis  \
# 0                                                       Запустить акцию, дающую скидку на товар в день рождения
# 1            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 2              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 3          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 4  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 5                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# 6                      Добавить страницу отзывов клиентов о магазине, что позволит увеличить количество заказов
# ...

# %% [markdown]
# Согласно фреймворка `ICE`: <br>
# Наивысшим приоритетом обладает гипотеза `Запустить акцию, дающую скидку на товар в день рождения` с рейтингом в 16.2 пункта. <br>
# На втором месте `Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей` с 13.3 пунктами. <br>
# На третьем месте `Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок` с 11.2 пунктами.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Принято!
# </div>

# %% [markdown]
# Рассчитаем значения для фреймфорка RICE (R от англ. reach, «охват»).

# %%
hypothesis['rice'] = round(hypothesis['reach'] * hypothesis['impact'] * hypothesis['confidence'] / hypothesis['efforts'], 1)
hypothesis.sort_values(['rice','ice'], ascending = False)
# Out:
#                                                                                                      hypothesis  \
# 7              Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок
# 2  Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа
# 0            Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей
# 6          Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию
# 8                                                       Запустить акцию, дающую скидку на товар в день рождения
# 3           Изменить структура категорий, что увеличит конверсию, т.к. пользователи быстрее найдут нужный товар
# 1                                     Запустить собственную службу доставки, что сократит срок доставки заказов
# ...

# %% [markdown]
# Согласно же фреймворка `RICE`: <br>
# Наивысшим приоритетом обладает гипотеза `Добавить форму подписки на все основные страницы, чтобы собрать базу клиентов для email-рассылок` с 112 пунктами, которая по фреймворку `ICE` была на 3 месте за счёт показателя `охват`, равного 10. `Запустить акцию, дающую скидку на товар в день рождения` с рейтингом в 16.2 пункта перемещается на 5 место из-за показателя `охват`, равного 1. <br>
# На втором месте `Добавить блоки рекомендаций товаров на сайт интернет магазина, чтобы повысить конверсию и средний чек заказа` с 56 пунктами с показателем `охват` - 8. <br>
# На третьем месте `Добавить два новых канала привлечения трафика, что позволит привлекать на 30% больше пользователей` с 40 единицами, который по фреймворку `ICE` располагается втором месте.	<br>
# `Показать на главной странице баннеры с актуальными акциями и распродажами, чтобы увеличить конверсию` имеет также 40 пунктов по фреймворку `RICE`, но располагается на 4 позиции, т.к. по `ICE` имеет только 8 пунктов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Отлично, что вывел таблицу дважды и применил сортировку по одному из фреймворков - так мы более наглядно можем наблюдать различия в их работе!
# </div>

# %% [markdown]
# <b>Вывод:</b><br>
# Приоретизация у `ICE` и `RICE` схожие, но за счёт того, что `ICE` не учитывает `охват` аудитории, лидирующие гипотезы в двую фреймворках различаются, подчас значительно.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Совершенно верно!
# </div><br/>

# %% [markdown]
# # Часть 2. Анализ A/B-теста

# %%
#Чтение файлов с результатами A/B-тестов:
orders = pd.read_csv('/datasets/orders.csv')
visitors = pd.read_csv('/datasets/visitors.csv')

# %% [markdown]
# Проведем стандартную проверку данных. Сначала проверим df `orders`:

# %%
#Вывод 5 первых строк:
display(orders.head(5))

#Вывод 5 последних строк:
display(orders.tail(5))
# Out:
#    transactionId   visitorId        date  revenue group
# 0     3667963787  3312258926  2019-08-15     1650     B
# 1     2804400009  3642806036  2019-08-15      730     B
# 2     2961555356  4069496402  2019-08-15      400     A
# 3     3797467345  1196621759  2019-08-15     9759     B
# 4     2282983706  2322279887  2019-08-15     2308     B
#       transactionId   visitorId        date  revenue group
# 1192     2662137336  3733762160  2019-08-14     6490     B
# 1193     2203539145   370388673  2019-08-14     3190     A
# 1194     1807773912   573423106  2019-08-14    10550     A
# 1195     1947021204  1614305549  2019-08-14      100     A
# 1196     3936777065  2108080724  2019-08-15   202740     B

# %%
#Вывод основной информации:
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1197 entries, 0 to 1196
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   transactionId  1197 non-null   int64
#  1   visitorId      1197 non-null   int64
#  2   date           1197 non-null   object
#  3   revenue        1197 non-null   int64
#  4   group          1197 non-null   object
# dtypes: int64(3), object(2)
# memory usage: 46.9+ KB

# %%
#Проверим размер дф:
orders.shape
# Out:
# (1197, 5)

# %%
#Вывод статистических данных:
orders.describe()
# Out:
#        transactionId     visitorId       revenue
# count   1.197000e+03  1.197000e+03  1.197000e+03
# mean    2.155621e+09  2.165960e+09  8.348006e+03
# std     1.229085e+09  1.236014e+09  3.919113e+04
# min     1.062393e+06  5.114589e+06  5.000000e+01
# 25%     1.166776e+09  1.111826e+09  1.220000e+03
# 50%     2.145194e+09  2.217985e+09  2.978000e+03
# 75%     3.237740e+09  3.177606e+09  8.290000e+03
# max     4.293856e+09  4.283872e+09  1.294500e+06

# %%
#Проверим пропуски:
orders.isna().sum()
# Out:
# transactionId    0
# visitorId        0
# date             0
# revenue          0
# group            0
# dtype: int64

# %%
#Рассмотрим явные дубликаты:
print(f'Количество явных дубликатов: {orders.duplicated().sum()}')
# Out:
# Количество явных дубликатов: 0

# %% [markdown]
# Основное по `orders`: <br>
# размер дф: 5 колонок, 1197 записей. <br>
# Явных дублей нет, пропуски отсутствуют. <br>
# Требуется переименовать нескольких колонок: `transactionId` и `visitorId`. <br>
# Тип данных в колонке `date` требуется привести к типу дат. <br>

# %% [markdown]
# Проверим дф `visitors`:

# %%
#Вывод 5 первых строк:
display(visitors.head(5))

#Вывод 5 последних строк:
display(visitors.tail(5))
# Out:
#          date group  visitors
# 0  2019-08-01     A       719
# 1  2019-08-02     A       619
# 2  2019-08-03     A       507
# 3  2019-08-04     A       717
# 4  2019-08-05     A       756
#           date group  visitors
# 57  2019-08-27     B       720
# 58  2019-08-28     B       654
# 59  2019-08-29     B       531
# 60  2019-08-30     B       490
# 61  2019-08-31     B       718

# %%
#Вывод основной информации:
visitors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      62 non-null     object
#  1   group     62 non-null     object
#  2   visitors  62 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 1.6+ KB

# %%
#Проверим размер дф:
visitors.shape
# Out:
# (62, 3)

# %%
#Вывод статистических данных:
visitors.describe()
# Out:
#          visitors
# count   62.000000
# mean   607.290323
# std    114.400560
# min    361.000000
# 25%    534.000000
# 50%    624.500000
# 75%    710.500000
# max    770.000000

# %%
#Построим график распределения количества пользователей:
visitors.hist(bins = 20)
# Out:
# array([[<AxesSubplot:title={'center':'visitors'}>]], dtype=object)

# %% [markdown]
# Предварительно, график выглядит сомнительно.

# %%
#Проверим пропуски:
visitors.isna().sum()
# Out:
# date        0
# group       0
# visitors    0
# dtype: int64

# %%
#Рассмотрим явные дубликаты:
print(f'Количество явных дубликатов: {visitors.duplicated().sum()}')
# Out:
# Количество явных дубликатов: 0

# %% [markdown]
# Основное по `visitors`: <br>
# размер дф: 3 колонки, 62 записи. <br>
# Явных дублей нет, пропуски отсутствуют. <br>
# Наименования колонок корректные. <br>
# Тип данных в колонке `date` требуется привести к типу дат. <br>

# %% [markdown]
# <b>Вывод:</b><br>
# Анализируется 2 дф `orders` (1197 записей) и `visitors` (62 записи).
# В обоих дф отсутствуют явные дубли и незаполненные поля.
# В обоих дф присутствует колонка `date`, тип которой необходимо привести к типу дат.
# В дф `orders` требуется привести наименования колонок `transactionId` и `visitorId` к требуемому виду.

# %%
# Переименования колонок в df 'orders':
orders = orders.rename(columns={'transactionId':'transaction_id', 'visitorId':'visitor_id'})
#Вывод первых 5 строк:
display(orders.head(5))
# Out:
#    transaction_id  visitor_id        date  revenue group
# 0      3667963787  3312258926  2019-08-15     1650     B
# 1      2804400009  3642806036  2019-08-15      730     B
# 2      2961555356  4069496402  2019-08-15      400     A
# 3      3797467345  1196621759  2019-08-15     9759     B
# 4      2282983706  2322279887  2019-08-15     2308     B

# %%
#Приведение типов колонок к корректному типу (даты):
#orders:
orders['date'] = pd.to_datetime(orders['date'])

#visitors:
visitors['date'] = pd.to_datetime(visitors['date'])

#проверка типов:
print(orders.dtypes,'\n')
print(visitors.dtypes)
# Out:
# transaction_id             int64
# visitor_id                 int64
# date              datetime64[ns]
# revenue                    int64
# group                     object
# dtype: object
#
# date        datetime64[ns]
# group               object
# visitors             int64
# dtype: object

# %% [markdown]
# Наименования колонок приведены к требуемому виду, тип колонок приведен к требуемому типу. Займемся анализом.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Типы данных заменили, убедились в корректности данных, можем двигаться дальше!
# </div><br/>

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Можно лучше⚠️:</b> Также рекомендую проанализировать:
# 1. Количество групп в АВ-тесте;
# 2. Даты начала и окончания теста;
# 3. Количество пользователей в каждой группе - по таблице с заказами;
# 4. Вероятность попадания пользователей в обе группы - по таблице с заказами.
#
# С помощью дополнительного анализа мы удостоверимся в корректности данных, сможем избежать ошибок, а также это пригодится тебе в будущем, например, при решении финального проекта:)
# </div>

# %%
# Количество групп:
print(f"Количество анализируемых групп: {orders['group'].nunique()}\n")

# Даты начала и окончания теста:
print(f"Начальная дата теста: {orders['date'].min():%d-%m-%Y}\nДата окончания теста: {orders['date'].max():%d-%m-%Y}\n")

#Количество пользователей в каждой группе (после очисти по "id посетителя" и "группе"):
cleared_orders = orders.drop_duplicates(subset=['visitor_id', 'group'])
pivot = display(cleared_orders.pivot_table(index='group', values='visitor_id', aggfunc='count'))

#Количество пользователей, находящихся в обеих группах:
two_grouped = cleared_orders[(cleared_orders['group'] == 'B') & (cleared_orders['visitor_id'].isin(cleared_orders[cleared_orders['group'] == 'A']['visitor_id']))]['visitor_id']
print(f'Количество пользователей, которые находятся в обоих группах: {len(two_grouped)}\nВероятность попасть в обе группы составляет {len(two_grouped)/len(cleared_orders):.1%}')
# Out:
# Количество анализируемых групп: 2
#
# Начальная дата теста: 01-08-2019
# Дата окончания теста: 31-08-2019
#        visitor_id
# group
# A             503
# B             586
# Количество пользователей, которые находятся в обоих группах: 58
# Вероятность попасть в обе группы составляет 5.3%

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b> <br>
# Спасибо, Евгения!<br>
# Выше вывел требую информацию в едином поле через пустую строку.<br>
# Учту в следующих работах.
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <s="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Отлично!
# </div>

# %% [markdown]
# ### Построить график кумулятивной выручки по группам.

# %% [markdown]
# Создадим массив уникальных пар значений дат и групп теста

# %%
datesGroups = orders[['date','group']].drop_duplicates()

# %% [markdown]
# Получим новый датасет, содержащий кумулятивные данные:

# %%
 # получаем агрегированные кумулятивные по дням данные о заказах  
ordersAggregated = datesGroups.apply(lambda x: orders[np.logical_and(orders['date'] <= x['date'], orders['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'transaction_id': pd.Series.nunique, 'visitor_id' : pd.Series.nunique, 'revenue' : 'sum'}), axis=1).sort_values(by=['date','group'])

# получаем агрегированные кумулятивные по дням данные о посетителях
visitorsAggregated = datesGroups.apply(lambda x: visitors[np.logical_and(visitors['date'] <= x['date'], visitors['group'] == x['group'])].agg({'date' : 'max', 'group' : 'max', 'visitors' : 'sum'}), axis=1).sort_values(by=['date','group']) 

# объединяем кумулятивные данные в одной таблице и присваиваем ее столбцам понятные названия 
cummulativeData = ordersAggregated.merge(visitorsAggregated, left_on=['date', 'group'], right_on=['date', 'group']) 
cummulativeData.columns = ['date', 'group', 'orders', 'buyers', 'revenue', 'visitors']

# %% [markdown]
# Построим графики кумулятивной выручки по дням и группам A/B-тестирования:

# %%
# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе А 
cummulativeRevenueA = cummulativeData[cummulativeData['group']=='A'][['date','revenue', 'orders']] 

# датафрейм с кумулятивным количеством заказов и кумулятивной выручкой по дням в группе B 
cummulativeRevenueB = cummulativeData[cummulativeData['group']=='B'][['date','revenue', 'orders']]

# Заведем поле для построения графика с размером 15*6
plt.figure(figsize=(15, 6)) 

# Строим график выручки группы А \
plt.plot(cummulativeRevenueA['date'], cummulativeRevenueA['revenue'], label='A',) 

# Строим график выручки группы B 
plt.plot(cummulativeRevenueB['date'], cummulativeRevenueB['revenue'], label='B') 

#Общие настройки визуализации:
plt.title('График накопительной выручки по группам')                         # вывод наименования графика
plt.xlabel('Дата', fontsize=14)                                              # вывод наименования оси X с размером 14
plt.xticks(rotation=30)                                                      # изменение угла вывода обозначений оси X
plt.grid()                                                                   # вывод на поле графиков дополнительных осей (axis='x',axis='y',axis='both' - both по определению, если ничего не присвоено)
plt.ylabel('Выручка', fontsize=14)                                           # вывод наименования оси У с размером 14 
plt.legend()                                                                 # вывод легенды
plt.show()                                                                   # вывод графика

# %% [markdown]
# <b>Вывод:</b><br>
# По графику можно отметить, что накопительная выручка по группам имеет стабильную динамику, но стоит отметить, что имеются всплески в группе `A`: 13 августа 2019 года и 29 августа 2019 года. В группе `B` 09 августа 2019 года, 15 августа 2019 года, а также крайне мощный всплеск 19 августа 2019 года.

# %% [markdown]
# <div class="alert alert-warning">
#     <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Можно лучше⚠️:</b> Как ты думаешь, с чем связаны данные всплески?
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b> <br>
# Всплески по датам связаны с тем, что в указанные даты происходили единичные сделки, стоимость которых почти достигала суммарного  среднедневного расхода по группе, а иногда и превышала, например в группе `B` за 15.08.2019, а также за 19.08.2019.
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <s="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Согласна, все может быть!
# </div>

# %%
#Проверка всплесков стоимости заказов:
# Группа 'A':
group_A_orders = orders[orders['group']=='A'].pivot_table(index='date', values='revenue', aggfunc='sum')
print('Топ-3 даты по расходам группы A:')
display(group_A_orders.sort_values(by='revenue',ascending=False).head(3))
print(f"При среднем расходе по группе A в день: {group_A_orders['revenue'].mean():.1f}")

# Рассмотрим отдельно каждую дату:
dates_A = ['2019-08-29', '2019-08-27', '2019-08-13']
print('\n\nИнформация по максимальной стоимости сделки за день и итоговом количестве сделок за день в группе:')
display(orders[(orders['group']=='A') & (orders['date'].isin(dates_A))].sort_values(by='revenue',ascending=False).groupby('date').agg({'revenue':'max', 'group':'count'}).rename(columns={'revenue':'revenue_max', 'group':'count'}).sort_values(by='revenue_max',ascending=False))
# Out:
# Топ-3 даты по расходам группы A:
#             revenue
# date
# 2019-08-29   320690
# 2019-08-27   286780
# 2019-08-13   263638
# При среднем расходе по группе A в день: 131767.8
#
#
# Информация по максимальной стоимости сделки за день и итоговом количестве сделок за день в группе:
#             revenue_max  count
# date
# 2019-08-27        93940     28
# 2019-08-13        92550     14
# 2019-08-29        78990     22

# %%
# Группа 'B':
group_A_orders = orders[orders['group']=='B'].pivot_table(index='date', values='revenue', aggfunc='sum')
print('Топ-3 даты по расходам группы B:')
display(group_A_orders.sort_values(by='revenue',ascending=False).head(3))
print(f"При среднем расходе по группе B в день: {group_A_orders['revenue'].mean():.1f}")

# Рассмотрим отдельно каждую дату:
dates_A = ['2019-08-19', '2019-08-15', '2019-08-06']
print('\n\nИнформация по максимальной стоимости сделки за день и итоговом количестве сделок за день в группе:')
display(orders[(orders['group']=='B') & (orders['date'].isin(dates_A))].sort_values(by='revenue',ascending=False).groupby('date').agg({'revenue':'max', 'group':'count'}).rename(columns={'revenue':'revenue_max', 'group':'count'}).sort_values(by='revenue_max',ascending=False))
# Out:
# Топ-3 даты по расходам группы B:
#             revenue
# date
# 2019-08-19  1429920
# 2019-08-15   342499
# 2019-08-06   242342
# При среднем расходе по группе B в день: 190572.9
#
#
# Информация по максимальной стоимости сделки за день и итоговом количестве сделок за день в группе:
#             revenue_max  count
# date
# 2019-08-19      1294500     21
# 2019-08-15       202740     31
# 2019-08-06        37550     28

# %% [markdown]
# ### Построить график кумулятивного среднего чека по группам.

# %% [markdown]
# Построим графики кумулятивного среднего чека по дням и группам A/B-тестирования:

# %%
# Заведем поле для построения графика с размером 15*6
plt.figure(figsize=(15, 6)) 

# Строим график выручки группы А 
plt.plot(cummulativeRevenueA['date'], cummulativeRevenueA['revenue']/cummulativeRevenueA['orders'], label='A') 

# Строим график выручки группы B 
plt.plot(cummulativeRevenueB['date'], cummulativeRevenueB['revenue']/cummulativeRevenueB['orders'], label='B') 

#Общие настройки визуализации:
plt.title('График накопительного среднего чека по группам')               # вывод наименования графика
plt.xlabel('Дата', fontsize=14)                                              # вывод наименования оси X с размером 14
plt.xticks(rotation=30)                                                      # изменение угла вывода обозначений оси X
plt.grid()                                                                   # вывод на поле графиков дополнительных осей (axis='x',axis='y',axis='both' - both по определению, если ничего не присвоено)
plt.ylabel('Средний чек', fontsize=14)                                           # вывод наименования оси У с размером 14 
plt.legend()                                                                 # вывод легенды
plt.show()                                                                   # вывод графика

# %% [markdown]
# <b>Вывод:</b><br>
# Накопительный средний чек группы `A` в начале месяца снижается с более чем в 6000 пунктов вплоть до примерно 5600 пунктов на 6.08.2019, далее до 13.08.2019 наблюдается исключительно рост, вплоть до почти 7500 пунктов (кроме 11.08.2019 - незначительная поправка в сторону снижения), далее до 18.08.2019 снижение до 6800, далее стабилизация в районе 6900 и с 23.08.2019 рост выше 7200 пунктов.
# Средний чек группы `B` до 08.08.2019 постоянно растёт с менее 5000 до более 7000 пунктов с единичным падением до менее 6000 пунктов 05.08.2019. Далее с 09.08.2019 идет плавное снижение показателя до 13.08.2019 до 6500 пунктов. Далее до 16.08.2019 снова средний чек растёт до 7000, стабилизируется и 19.08.2019 происходит резкий всплеск до показателя более 10000 пунктов, после 21.08.2019 наблюдается постепенное снижение показателя.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Молодец, верно, группа В нестабильна. Возможно, в данную группу в середине теста попали крупные заказы. Необходимо будет учесть этот факт при принятии решения о результатах A/B-теста:)
# </div>

# %% [markdown]
# ### Построить график относительного изменения кумулятивного среднего чека группы B к группе A.

# %%
# Заведем поле для построения графика с размером 15*6
plt.figure(figsize=(15, 6)) 

# собираем данные в одном датафрейме 
mergedCummulativeRevenue = cummulativeRevenueA.merge(cummulativeRevenueB, left_on='date', right_on='date', how='left', suffixes=['A', 'B']) 

# cтроим отношение средних чеков 
plt.plot(mergedCummulativeRevenue['date'], (mergedCummulativeRevenue['revenueB']/mergedCummulativeRevenue['ordersB'])/(mergedCummulativeRevenue['revenueA']/mergedCummulativeRevenue['ordersA'])-1) 

plt.title('График относительного изменения кумулятивного \nсреднего чека группы B к группе A.', fontsize=18)                  # вывод наименования графика
plt.xlabel('Дата', fontsize=14)                                              # вывод наименования оси X с размером 14
plt.xticks(rotation=30)                                                      # изменение угла вывода обозначений оси X
plt.grid()                                                                   # вывод на поле графиков дополнительных осей (axis='x',axis='y',axis='both' - both по определению, если ничего не присвоено)
plt.ylabel('Средний чек', fontsize=14)                                       # вывод наименования оси У с размером 14 

# добавляем ось X 
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %% [markdown]
# <b>Вывод:</b><br>
# По графику можно отметить, что накопительный средний чек группы `B` преобладал на протяжении почти всего анализируемого периода кроме начала периода (первые 2 дня) и в период с 12.08.2019 по 15.08.2019 с пиком 13.08.2019.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Отлично!
# </div>

# %% [markdown]
# ### Построить график кумулятивного среднего количества заказов на посетителя по группам.

# %%
cummulativeData['conversion'] = cummulativeData['orders'] / cummulativeData['visitors']
cummulativeConversionA = cummulativeData[cummulativeData['group'] == 'A']
cummulativeConversionB = cummulativeData[cummulativeData['group'] == 'B']

# %%
# Заведем поле для построения графика с размером 15*6
plt.figure(figsize=(15, 6)) 

# Строим график выручки группы А 
plt.plot(cummulativeConversionA['date'], cummulativeConversionA['conversion'], label='A') 

# Строим график выручки группы B 
plt.plot(cummulativeConversionB['date'], cummulativeConversionB['conversion'], label='B') 

#Общие настройки визуализации:
plt.title('График накопленного среднего количества заказов на посетителя по группам')               # вывод наименования графика
plt.xlabel('Дата', fontsize=14)                                              # вывод наименования оси X с размером 14
plt.xticks(rotation=30)                                                      # изменение угла вывода обозначений оси X
plt.grid()                                                                   # вывод на поле графиков дополнительных осей (axis='x',axis='y',axis='both' - both по определению, если ничего не присвоено)
plt.ylabel('Конверсия', fontsize=14)                                         # вывод наименования оси У с размером 14 
plt.legend()                                                                 # вывод легенды
plt.show()                                                                   # вывод графика

# %% [markdown]
# <b>Вывод:</b><br>
# По группе `A`: В начале анализируемого периода показатель находится на уровне 0.033, затем 03.08.2019 резко взлетает почти до 0.037 пунктов, затем 04.08.2019 снова опускается ниже 0.033 и в течение нескольких дней плавно опускается ниже 0.031. Дальше, после 09.08.2019 динамика рваная, скачкообразная (рост-падение) до конца периода в диапозоне 0.031 - 0.029. График заканчивается снижением до уровня ниже 0.03. Полагаю, на 03.08.2019 прихолось меньше всего посетителей (или не учтены).
# По группе `B`: График начинается с самой низкой точки (примерно 0.0295), затем резко подскакивает до почти 0.035, затем за 2 дня снижается до 0.03, после плавно растёт до своего пика выше 0.036 на 10.08.2019. Далее опускается до 0.034 на 14.08.2019 и уже не поднимается до 0.036, но пытается 16.08.2019. Далее плавное снижение до 0.033 и стабилизация на уровне примерно 0.034. Пики показателя у группы `B` также связаны с наименьшим количеством посетителей в эти даты, но не количеством заказов.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Супер, правильно!
# </div>

# %% [markdown]
# ### Построить график относительного изменения кумулятивного среднего количества заказов на посетителя группы `B` к группе `A`.

# %%
# Заведем поле для построения графика с размером 15*6
plt.figure(figsize=(15, 6)) 

# собираем данные в одном датафрейме 
mergedCummulativeConversion = cummulativeConversionA.merge(cummulativeConversionB, left_on='date', right_on='date', how='left', suffixes=['A', 'B']) 

# cтроим отношение средних чеков 
plt.plot(mergedCummulativeConversion['date'], mergedCummulativeConversion['conversionB']/mergedCummulativeConversion['conversionA']-1) 

plt.title('График относительного изменения накопленного среднего \nколичества заказов на посетителя группы B к группе A.', fontsize=18)                  # вывод наименования графика
plt.xlabel('Дата', fontsize=14)                                              # вывод наименования оси X с размером 14
plt.xticks(rotation=30)                                                      # изменение угла вывода обозначений оси X
plt.grid()                                                                   # вывод на поле графиков дополнительных осей (axis='x',axis='y',axis='both' - both по определению, если ничего не присвоено)
plt.ylabel('Конверсия', fontsize=14)                                         # вывод наименования оси У с размером 14 

# добавляем ось X 
plt.axhline(y=0, color='black', linestyle='--')
plt.show()

# %% [markdown]
# <b>Вывод:</b><br>
# Судя по графику, конверсия накопленных заказов к посетителям группы `A` ниже конверсии группы `B` на протяжении почти всего графика, исключение - первая неделя анализируемого месяца, а точнее 01.08.2019 число и период с 03.08.2019 по 05.08.2019.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b>  Хорошо, давай посмотрим на аномалии:)
# </div>

# %% [markdown]
# ### Построить точечный график количества заказов по пользователям.

# %%
#Сгруппируем заказы по посетителям, посчитаем количество заказов по каждому посетителю:
ordersByUsers = orders.groupby(by='visitor_id', as_index=False).agg({'transaction_id':'nunique'})

# Обзовём колонки:
ordersByUsers.columns = ['userId', 'orders']

# Отсортируем и выведем топ-10 посетителей по количеству заказов:
ordersByUsers.sort_values('orders', ascending=False).head(10)
# Out:
#           userId  orders
# 1023  4256040402      11
# 591   2458001652      11
# 569   2378935119       9
# 487   2038680547       8
# 44     199603092       5
# 744   3062433592       5
# 55     237748145       5
# 917   3803269165       5
# 299   1230306981       5
# 897   3717692402       5

# %%
# серия из чисел от 0 до количества наблюдений в ordersByUsers
x_values = pd.Series(range(0, len(ordersByUsers)))
plt.figure(figsize=(15, 6)) 
plt.scatter(x_values, ordersByUsers['orders']) 
plt.title('График количества заказов по пользователям.', fontsize=18)                # вывод наименования графика
plt.xlabel('Пользователи', fontsize=14)                                              # вывод наименования оси X с размером 14
plt.grid()                                                                           # вывод на поле графиков дополнительных осей (axis='x',axis='y',axis='both' - both по определению, если ничего не присвоено)
plt.ylabel('Заказы', fontsize=14)  
plt.show()

# %% [markdown]
# <b>Вывод:</b><br>
# По графику видно, что абсолютное большинство пользователей, сделавших заказ сделали его единожды за анализируемый период.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Верно!
# </div>

# %% [markdown]
# ### Посчитать 95-й и 99-й перцентили количества заказов на пользователя. Выбрать границу для определения аномальных пользователей.

# %%
# Заведём список требуемых персентилей:
perc_list=[95,99]

# С помощью цикла, выведем требуемую информацию по перцентилям:
for i in perc_list:
    print(f'Количество заказов, которые делают {100 - i}% пользователей {np.percentile(ordersByUsers["orders"], i)}') # Метод np.percentile('column', [percentile1, percentile2, percentile3]) находит перцентили.
# Out:
# Количество заказов, которые делают 5% пользователей 2.0
# Количество заказов, которые делают 1% пользователей 4.0

# %% [markdown]
# <b>Вывод:</b><br>
# Не более 5% пользователей оформляли больше 2 заказы. И 1% пользователей оформляли 4 и более заказа. <br>
# Полагаю, что более 4 заказов на пользователя, можно считать аномалией.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Отлично, идем дальше!
# </div>

# %% [markdown]
# ### Построить точечный график стоимостей заказов.

# %%
#Отсортируем и выведем топ-10 посетителей по количеству заказов:
print(orders.sort_values(by='revenue', ascending=False).head(10))
# Out:
#       transaction_id  visitor_id       date  revenue group
# 425        590470918  1920142716 2019-08-19  1294500     B
# 1196      3936777065  2108080724 2019-08-15   202740     B
# 858        192721366  1316129916 2019-08-27    93940     A
# 1136       666610489  1307669133 2019-08-13    92550     A
# 744       3668308183   888512513 2019-08-27    86620     B
# 682       1216533772  4266935830 2019-08-29    78990     B
# 662       1811671147  4266935830 2019-08-29    78990     A
# 743       3603576309  4133034833 2019-08-09    67990     A
# 1103      1348774318  1164614297 2019-08-12    66350     A
# 1099       316924019   148427295 2019-08-12    65710     A

# %%
x_values_rev = pd.Series(range(0, len(orders['revenue'])))


plt.figure(figsize=(15, 6)) 
plt.scatter(x_values_rev, orders['revenue'])
plt.title('График стоимостей заказов.', fontsize=18)                # вывод наименования графика
plt.xlabel('Пользователи', fontsize=14)                                              # вывод наименования оси X с размером 14
plt.grid()                                                                           # вывод на поле графиков дополнительных осей (axis='x',axis='y',axis='both' - both по определению, если ничего не присвоено)
plt.ylabel('Стоимость заказов', fontsize=14)  
plt.show()

# %% [markdown]
# <b>Вывод:</b><br>
# Во всей базе присутствует только 2 заказа дороже 100000 "пунктов" (1294500 и 202740).

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Правильно!
# </div>

# %% [markdown]
# ### Посчитать 95-й и 99-й перцентили стоимости заказов. Выбрать границу для определения аномальных заказов.

# %%
# С помощью цикла, выведем требуемую информацию по перцентилям:
for i in perc_list:
    print(f'Стоимость заказов заказов, которые делают {100 - i}% пользователей не превышает {np.percentile(orders["revenue"], i):.1f} пунктов')
# Out:
# Стоимость заказов заказов, которые делают 5% пользователей не превышает 28000.0 пунктов
# Стоимость заказов заказов, которые делают 1% пользователей не превышает 58233.2 пунктов

# %% [markdown]
# <b>Вывод:</b><br>
# Не более 5% пользователей оформляли заказы дороже 28000 пунктов. И 1% пользователей делали заказы стоимостью более 58233 пунктов.
# Предположим, что граница аномалий находится выше стоимости заказов 5%, допустим 30000.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Замечательное решение, молодец!
# </div>

# %% [markdown]
# ### Посчитать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «сырым» данным.

# %% [markdown]
# <b>Сформулируем гипотезы: </b> <br>
#  <b>Нулевая:  </b>различий в среднем количестве заказов между группами по "сырым" данным нет.<br>
#  <b>Альтернативная:  </b>различия в среднем между группами по "сырым" данным есть.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Гипотезы сформулированы верно!
# </div>

# %%
#Создадим новый дф с переименованными колонками: 
cummulativeData_2 = cummulativeData.rename(columns={'orders':'orders_cumm','buyers':'buyers_cumm','revenue':'revenue_cumm','visitors':'visitors_cumm'})

#выведем первые несколько строк, проверим, чтоб работало:
display(cummulativeData_2.head(3))
# Out:
#         date group  orders_cumm  buyers_cumm  revenue_cumm  visitors_cumm  \
# 0 2019-08-01     A           24           20        148579            719
# 1 2019-08-01     B           21           20        101217            713
# 2 2019-08-02     A           44           38        242401           1338
#
#    conversion
# 0    0.033380
# 1    0.029453
# 2    0.032885

# %%
# Создадим дф с посчитанными количеством сделок и суммарной стоимостью заказов в день по группам. 
orders_per_day = orders.groupby(by=['date','group'], as_index=False).agg({'transaction_id': pd.Series.nunique, 'revenue': 'sum'})

# Переименуем колонки, чтоб читаемо было:
orders_per_day.columns = ['date', 'group', 'orders_per_day', 'revenue_per_day']

# Выведем первые 5 строк:
orders_per_day.head(5)
# Out:
#         date group  orders_per_day  revenue_per_day
# 0 2019-08-01     A              24           148579
# 1 2019-08-01     B              21           101217
# 2 2019-08-02     A              20            93822
# 3 2019-08-02     B              24           165531
# 4 2019-08-03     A              24           112473

# %% [markdown]
# Разделим `cummulativeData_2` и `orders_per_day`, а также `visitors` на группы `A` и `B` и сведем в единый дф.

# %%
#Создадим дф cummulativeData_2 A и B:
cummulativeData_2A = cummulativeData_2[cummulativeData_2['group'] == 'A']
cummulativeData_2B = cummulativeData_2[cummulativeData_2['group'] == 'B']

# Переименуем колонки cummulativeData_2 A и B:
cummulativeData_2A = cummulativeData_2A.rename(columns={'orders_cumm':'orders_cumm_A', 
                                   'buyers_cumm':'buyers_cumm_A', 
                                   'revenue_cumm':'revenue_cumm_A',
                                  'visitors_cumm':'visitors_cumm_A'})

cummulativeData_2B = cummulativeData_2B.rename(columns={'orders_cumm':'orders_cumm_B', 
                                   'buyers_cumm':'buyers_cumm_B', 
                                   'revenue_cumm':'revenue_cumm_B',
                                  'visitors_cumm':'visitors_cumm_B'})

#удалим колонку с группой:
cummulativeData_2A = cummulativeData_2A.drop('group',axis = 1 )
cummulativeData_2B = cummulativeData_2B.drop('group',axis = 1 )

# Выведем для проверки 5 строк:
display(cummulativeData_2A.head())
display(cummulativeData_2B.head())
# Out:
#         date  orders_cumm_A  buyers_cumm_A  revenue_cumm_A  visitors_cumm_A  \
# 0 2019-08-01             24             20          148579              719
# 2 2019-08-02             44             38          242401             1338
# 4 2019-08-03             68             62          354874             1845
# 6 2019-08-04             84             77          425699             2562
# 8 2019-08-05            109            100          549917             3318
#
#    conversion
# 0    0.033380
# 2    0.032885
# 4    0.036856
# 6    0.032787
# 8    0.032851
#         date  orders_cumm_B  buyers_cumm_B  revenue_cumm_B  visitors_cumm_B  \
# 1 2019-08-01             21             20          101217              713
# 3 2019-08-02             45             43          266748             1294
# 5 2019-08-03             61             59          380996             1803
# 7 2019-08-04             78             75          489567             2573
# ...

# %%
#Создадим дф cummulativeData_2 A и B:
orders_per_dayA = orders_per_day[orders_per_day['group'] == 'A']
orders_per_dayB = orders_per_day[orders_per_day['group'] == 'B']

# Переименуем колонки cummulativeData_2 A и B:
orders_per_dayA = orders_per_dayA.rename(columns={'orders_per_day':'orders_per_day_A', 
                                   'revenue_per_day':'revenue_per_day_A'})

orders_per_dayB = orders_per_dayB.rename(columns={'orders_per_day':'orders_per_day_B', 
                                   'revenue_per_day':'revenue_per_day_B'})

#удалим колонку с группой:
orders_per_dayA = orders_per_dayA.drop('group',axis = 1 )
orders_per_dayB = orders_per_dayB.drop('group',axis = 1 )

# Выведем для проверки 5 строк:
display(orders_per_dayA.head())
display(orders_per_dayB.head())
# Out:
#         date  orders_per_day_A  revenue_per_day_A
# 0 2019-08-01                24             148579
# 2 2019-08-02                20              93822
# 4 2019-08-03                24             112473
# 6 2019-08-04                16              70825
# 8 2019-08-05                25             124218
#         date  orders_per_day_B  revenue_per_day_B
# 1 2019-08-01                21             101217
# 3 2019-08-02                24             165531
# 5 2019-08-03                16             114248
# 7 2019-08-04                17             108571
# 9 2019-08-05                23              92428

# %%
#Создадим дф visitors_per_day A и B:
visitors_per_dayA = visitors[visitors['group'] == 'A']
visitors_per_dayB = visitors[visitors['group'] == 'B']

# Переименуем колонки cummulativeData_2 A и B:
visitors_per_dayA = visitors_per_dayA.rename(columns={'visitors':'visitors_per_day_A'})

visitors_per_dayB = visitors_per_dayB.rename(columns={'visitors':'visitors_per_day_B'})

#удалим колонку с группой:
visitors_per_dayA = visitors_per_dayA.drop('group',axis = 1 )
visitors_per_dayB = visitors_per_dayB.drop('group',axis = 1 )

# Выведем для проверки 5 строк:
display(visitors_per_dayA.head())
display(visitors_per_dayB.head())
# Out:
#         date  visitors_per_day_A
# 0 2019-08-01                 719
# 1 2019-08-02                 619
# 2 2019-08-03                 507
# 3 2019-08-04                 717
# 4 2019-08-05                 756
#          date  visitors_per_day_B
# 31 2019-08-01                 713
# 32 2019-08-02                 581
# 33 2019-08-03                 509
# 34 2019-08-04                 770
# 35 2019-08-05                 707

# %%
# Объединение в дф 'data'
data = (orders_per_dayA.merge(orders_per_dayB, left_on='date', right_on='date', how='left')
    .merge(cummulativeData_2A, left_on='date', right_on='date', how='left')
    .merge(cummulativeData_2B, left_on='date', right_on='date', how='left')
    .merge(visitors_per_dayA, left_on='date', right_on='date', how='left')
    .merge(visitors_per_dayB, left_on='date', right_on='date', how='left'))

# Вывод 5 строк:
data.head(5)
# Out:
#         date  orders_per_day_A  revenue_per_day_A  orders_per_day_B  \
# 0 2019-08-01                24             148579                21
# 1 2019-08-02                20              93822                24
# 2 2019-08-03                24             112473                16
# 3 2019-08-04                16              70825                17
# 4 2019-08-05                25             124218                23
#
#    revenue_per_day_B  orders_cumm_A  buyers_cumm_A  revenue_cumm_A  \
# 0             101217             24             20          148579
# 1             165531             44             38          242401
# 2             114248             68             62          354874
# 3             108571             84             77          425699
# 4              92428            109            100          549917
#
#    visitors_cumm_A  conversion_x  orders_cumm_B  buyers_cumm_B  \
# 0              719      0.033380             21             20
# ...

# %%
# Сведём данные по количеству заказов на посетителя по группам:
orders_by_users_A = (
    orders[orders['group'] == 'A']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique}))

orders_by_users_B = (
    orders[orders['group'] == 'B']
    .groupby('visitor_id', as_index=False)
    .agg({'transaction_id': pd.Series.nunique}))

# Назначаем наименования колонок:
orders_by_users_A.columns = ['visitor_id', 'orders']
orders_by_users_B.columns = ['visitor_id', 'orders']

# Выведем первые 3 строки дф:
display(orders_by_users_A.sort_values(by = 'orders', ascending=False).head(3))
display(orders_by_users_B.sort_values(by = 'orders', ascending=False).head(3))
# Out:
#      visitor_id  orders
# 499  4256040402       7
# 227  2038680547       5
# 278  2458001652       5
#      visitor_id  orders
# 340  2458001652       6
# 326  2378935119       5
# 501  3717692402       4

# %%
# Объявим переменные sample_A и sample_B, в которых пользователям с заказами будет соответствовать число заказов пользователя. А пользователям без заказов — нули.
sample_A = pd.concat([orders_by_users_A['orders'],pd.Series(
            0,index=np.arange(data['visitors_per_day_A'].sum() - len(orders_by_users_A['orders'])),name='orders',),],axis=0)
sample_B = pd.concat([orders_by_users_B['orders'], pd.Series(
            0, index=np.arange( data['visitors_per_day_B'].sum() - len(orders_by_users_B['orders'])), name='orders',),],axis=0)

# %% [markdown]
# Проверим критерием Манна-Уитни.

# %%
print("P-value равен","{0:.3f}".format(st.mannwhitneyu(sample_A, sample_B)[1]))

print(r'Относительный прирост средней конверсии группы "B" к конверсии группы "A" равен', "{0:.1%}".format(sample_B.mean() / sample_A.mean() - 1))
# Out:
# P-value равен 0.017
# Относительный прирост средней конверсии группы "B" к конверсии группы "A" равен 13.8%

# %% [markdown]
# <b>Вывод:</b><br>
# Так как P-value значительно меньше 0.05, потому нулевую гипотезу отвергаем. Анализ «сырых данных» сообщает, что в среднем количестве заказов между группами есть статистически значимые различия. Относительный прирост среднего группы B к конверсии группы A равен 13.8%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Хорошо!
# </div>

# %% [markdown]
# ### Посчитать статистическую значимость различий в среднем чеке заказа между группами по «сырым» данным.

# %% [markdown]
# <b>Сформулируем гипотезы: </b> <br>
# <b>Нулевая:  </b>различий в среднем чеке заказов между группами по "сырым" данным нет.<br>
# <b>Альтернативная:  </b>различия в среднем чеке между группами по "сырым" данным есть.

# %%
print("P-value равен",'{0:.3f}'.format(st.mannwhitneyu(orders[orders['group']=='A']['revenue'], orders[orders['group']=='B']['revenue'])[1]))
print("Относительный прирост среднего чека группы B к среднему чеку группы A равен", '{0:.1%}'.format(orders[orders['group']=='B']['revenue'].mean()/orders[orders['group']=='A']['revenue'].mean()-1))
# Out:
# P-value равен 0.729
# Относительный прирост среднего чека группы B к среднему чеку группы A равен 25.9%

# %% [markdown]
# <b>Вывод:</b><br>
# Так как P-value значительно больше 0.05, поэтому нулевую гипотезу отвергнуть не можем. Анализ «сырых данных» сообщает, что в среднем чеке между группами отсутствуют статистически значимые различия. Относительный прирост среднего чека группы `B` к среднему чеку группы `A` почти 26%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Согласна!
# </div>

# %% [markdown]
# ### Посчитать статистическую значимость различий в среднем количестве заказов на посетителя между группами по «очищенным» данным.

# %% [markdown]
# Приступаем к подготовке очищенных от аномалий данных. <br>
# Напомним, что 95-й и 99-й перцентили средних чеков равны 28000 и 58233.2 пунктам. <br>
# Аномалией принял решения считать заказы дороже 30000 пунктов. <br>
# А 95-й и 99-й перцентили числа заказов на одного пользователя равны 2 и 4 заказам на пользователя. <br>
# Аномалия - 4 и более заказов на пользователя. <br>
# Удалять нужно именно пользователей — сначала определим аномальные заказы. Затем пользователей, совершивших их, и добавим их в список аномальных.

# %%
# Создадим срезы пользователей, с числом заказов равным или больше 4
users_with_many_orders = pd.concat([
    orders_by_users_A[orders_by_users_A['orders'] >= 4]['visitor_id'],
    orders_by_users_B[orders_by_users_B['orders'] >= 4]['visitor_id'],
    ], axis=0)

# Создадим срезы пользователей, совершивших заказы дороже 30000
users_with_expensive_orders = orders[orders['revenue'] > 30000]['visitor_id']

# Объединим их в таблицу, удалим дубликаты, отсортируем по возрастанию.
abnormal_users = pd.concat([users_with_many_orders, users_with_expensive_orders], axis=0).drop_duplicates().sort_values(ascending=False)

# Выведем несколько пользователей с аномальными заказами:
print(abnormal_users.head(5))
# Out:
# 662    4266935830
# 499    4256040402
# 743    4133034833
# 627    4120364173
# 940    4003628586
# Name: visitor_id, dtype: int64

# %%
# Создадим переменные sample_A_filtered и sample_B_filtered, в которых сохраним очищенные данные о заказах — не включая аномальных пользователей.
sample_A_filtered = pd.concat([orders_by_users_A[np.logical_not(orders_by_users_A['visitor_id'].isin(abnormal_users))]['orders'],pd.Series(
            0,index=np.arange(data['visitors_per_day_A'].sum() - len(orders_by_users_A['orders'])),name='orders',),],axis=0)

sample_B_filtered = pd.concat([orders_by_users_B[np.logical_not(orders_by_users_B['visitor_id'].isin(abnormal_users))]['orders'],pd.Series(
            0,index=np.arange(data['visitors_per_day_B'].sum() - len(orders_by_users_B['orders'])),name='orders',),],axis=0)

# %%
# Посчитаем статистическую значимость различия среднего количества заказов после удаления аномальных пользователей:
print("P-value равен","{0:.3f}".format(st.mannwhitneyu(sample_A_filtered, sample_B_filtered)[1]))
print(r'Относительный прирост средней конверсии группы "B" к конверсии группы "A" равен', "{0:.1%}".format(sample_B_filtered.mean()/sample_A_filtered.mean()-1))
# Out:
# P-value равен 0.018
# Относительный прирост средней конверсии группы "B" к конверсии группы "A" равен 14.8%

# %% [markdown]
# <b>Вывод:</b><br>
# Очищенные данные от "сырых" отличаются не значительно, выводы похожие: <br>нулевая гипотеза отвергнута, разница конверсия выросла в пользу группы `B` до 14.8%.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Супер, двигаемся дальше!
# </div>

# %% [markdown]
# ### Посчитать статистическую значимость различий в среднем чеке заказа между группами по «очищенным» данным.

# %%
print("P-value равен",'{0:.3f}'.format(st.mannwhitneyu(orders[np.logical_and(orders['group']=='A',np.logical_not(orders['visitor_id'].isin(abnormal_users)),)    
]['revenue'], orders[np.logical_and(orders['group']=='B',np.logical_not(orders['visitor_id'].isin(abnormal_users)),)]['revenue'])[1]))

print("Относительный прирост среднего чека группы B к среднему чеку группы A равен", '{0:.1%}'
      .format(orders[np.logical_and(orders['group'] == 'B', np.logical_not(orders['visitor_id'].isin(abnormal_users)))]['revenue'].mean()
             /orders[np.logical_and(orders['group'] == 'A', np.logical_not(orders['visitor_id'].isin(abnormal_users)))]['revenue'].mean()- 1))
# Out:
# P-value равен 0.958
# Относительный прирост среднего чека группы B к среднему чеку группы A равен -2.0%

# %% [markdown]
# <b>Вывод:</b><br>
# P-value после очистки от аномальных пользователей еще сильнее вырос, отвергнуть нулевую гипотезу не получается - различий в среднем чеке между группами нет. Также стоит отметить, что относительные различия среднего чека между группами изменились и теперь группа `A` преобладает на 2% над группой `B`.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Отлично!
# </div>

# %% [markdown]
# ### Принять решение по результатам теста и объясните его.

# %% [markdown]
# <b>Основное:</b><br>
# 1. Присутствует статистически значимое различие по среднему количеству заказов между группами как по «сырым», так и  по данным после фильтрации аномалий;<br>
# 2. По среднему количеству заказов на посетителя группа `B`лидирует, по сравнению с группой `A`. После фильтрации аномалий отрыв `B` от `A` вырос с 13.8% до 14.8%.<br>
# 3. Нет статистически значимого различия по среднему чеку между группами ни по «сырым», ни по данным после фильтрации аномалий;<br>
# 4. По относительному среднему чеку заказов группа `B`лидирует, по сравнению с группой `A` до фильтрации от аномалий на 25.9%. После фильтрации аномалий отрыв `B` от `A` не просто сократился, а стал отрицательным, то есть, группа `A` стала лидером. До фильтрации аномалий по  группа `B` по отношению к группе `A`   <br>
#
# <b>Итог:</b><br>
# Полагаю, имеет смысл остановить дальнейший тест, признать его успешным, назначить группу `B` победителем.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Решение на этом шаге является полностью правильным. Ты здорово разобрался во влиянии выбросов на результаты сравнения средних значений и отметил преимущество статистического теста при интерпретации результатов.
# </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
# Давай подведем итоги. Ты большой молодец, что старался и проделал такую большую работу. Мне понравилось, что ты наполнил проект развернутыми выводами и наглядно продемонстрировал каждое задание:)  Очень хорошая работа получилась!
#
#     Разберем над чем стоит поработать:
#
#     1. Рекомендую:
#     - провести доп. исследование датафреймов.
#
#     Пересмотри работу и исправь ошибки. Обязательно пиши, если я могу тебе еще чем-то помочь. Удачи!)
#
# ![](https://media.giphy.com/media/xUKrrEnN9I5lnrcSMv/giphy-downsized-large.gif)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента: </b> <br>
# Евгения, спасибо, что проверили работу и дали обратную связь!
# Надеюсь, корректно понял недоработки и доработал верно.
# Спасибо еще раз и хорошего дня!
#
# </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <s="tocSkip"> </h2>
#
# <b>Отлично!✅:</b> Паша, молодец, оперативно и верно доработал парочку рекомендаций. Благодарю за обратную связь, работа принята, удачи в обучении!)
# </div>
